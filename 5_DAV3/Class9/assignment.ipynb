# %%
from scipy.stats import pearsonr, spearmanr
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Q2. Father and Son
# Child development researchers studying growth patterns of children collect data on the height of fathers and sons.
#
# Analyse the correlation between the father's height and their son's height using the given data

# %%
Father_Height = [169.39, 161.91, 159.23, 161.72, 167.52, 152.13, 169.64, 162.56, 154.92, 158.57, 153.17, 159.56, 153.77, 168.02, 157.75, 157.42, 160.65, 160.09, 151.4, 151.05, 136.94, 163.56, 160.39, 146.92, 171.66, 150.48, 158.12, 157.83, 163.99, 164.95]  
Son_Height = [187.35, 177.8, 181.85, 190.69, 188.07, 168.16, 181.65, 173.94, 174.28, 177.87, 176.01, 185.18, 180.33, 175.85, 178.11, 177.34, 185.46, 173.56, 177.19, 169.02, 157.13, 179.58, 181.05, 169.8, 190.89, 164.82, 175.32, 173.69, 185.73, 185.29]

df = pd.DataFrame({'Father':Father_Height, 'Son':Son_Height})
corr = df.corr()
print(f'positive corelation as the value is near to 1')
corr
# Out:
# positive corelation as the value is near to 1
#           Father       Son
# Father  1.000000  0.800205
# Son     0.800205  1.000000

# %% [markdown]
# #### Q4. Exam score and Study hours
# A researcher is analyzing the relationship between the number of hours students spend studying and their exam scores. He collects data from 10 students:
#
# study_hours = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])
# exam_scores = np.array([60, 65, 70, 75, 80, 85, 90, 95, 100, 105])
#
# Calculate the Pearson correlation coefficient between these variables.

# %%
study_hours = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50, 55])  
exam_scores = np.array([60, 65, 70, 75, 80, 85, 90, 95, 100, 105])
p_stat, p_value = pearsonr(study_hours,exam_scores)
print(f'coefficient: {p_stat:.3f}, p_value: {p_value:.8f}')
# Out:
# coefficient: 1.000, p_value: 0.00000000

# %% [markdown]
# ### Q6. compute pearson and spearman
# Compute the pearson and spearman correlation between two variables a and b .

# %%
a = [10.0, 8.0, 13.0, 9.0, 11.0, 14.0, 6.0, 4.0, 12.0, 7.0, 5.0]
b = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]

p_coeff, p_pvalue = pearsonr(a,b)
sp_coeff, sp_pvalue = spearmanr(a,b)

print(f'Pearson: {p_coeff:.5f}, Spearman:{sp_coeff:.5f}')
# Out:
# Pearson: 0.81642, Spearman:0.81818

# %% [markdown]
# ### Q7. Sunlight and Height
# A biologist is studying the relationship between the height of plants and the amount of sunlight they receive.<br/>
# The biologist collects data from 8 different plants, measuring their heights (in centimeters) and ranking them based on the amount of sunlight they receive.<br/>
#
# plant_heights = np.array([15, 20, 25, 18, 22, 30, 28, 35])<br/>
# sunlight_rankings = np.array([4, 7, 3, 6, 5, 8, 2, 1])
#
#
# Calculate the Spearman correlation between these variables.

# %%
plant_heights = np.array([15, 20, 25, 18, 22, 30, 28, 35])
sunlight_rankings = np.array([4, 7, 3, 6, 5, 8, 2, 1])

spearmanr(plant_heights,sunlight_rankings)
# Out:
# SignificanceResult(statistic=np.float64(-0.3333333333333334), pvalue=np.float64(0.4197530864197531))

# %% [markdown]
# ### Q8. Fertilizer & Yield
# An agricultural study investigates the relationship between the amount of fertilizer applied (kg/hectare) and the yield of a specific crop (tons/hectare) on different plots. Data from 30 plots are collected.<br/>
# Which of the following statements about Spearman's rank correlation coefficient (rho) between fertilizer and yield in this dataset are true?

# %%
#(kg/hectare)
Fertilizer =  [21, 21, 29, 34, 46, 46, 56, 69, 70, 67, 73, 83, 78, 87, 100, 102, 118, 111, 114, 120, 130, 135, 153, 145, 153, 162, 163, 172, 176, 184]  
#(tons/hectare)
Yield = [18.118, 8.718, 10.918, 12.388, 15.068, 14.068, 16.528, 19.478, 19.01, 19.322, 9.942, 20.722, 20.232, 21.362, 20.8, 20.792, 2.152, 21.058, 2.208, 10.5, 19.1, 18.25, 15.082, 16.75, 14.982, 13.512, 1.362, 1.932, 9.248, 6.988]

spearmanr(Fertilizer,Yield)
# Out:
# SignificanceResult(statistic=np.float64(-0.2732836471391437), pvalue=np.float64(0.14395625214119626))

# %%
sns.scatterplot(x=Fertilizer, y=Yield)
# Out:
# <Axes: >

# %%
df = pd.DataFrame({'Fertilizer':Fertilizer,'Yield':Yield})
sns.set(font_scale=1.0)
plt.figure(figsize=(10,8))
correlation_values = df.corr(method = 'pearson')
sns.heatmap(correlation_values, vmax = .6, linewidths=0.01, square=True, annot=True, cmap="RdBu", linecolor="black")
plt.title('Correlation between features');
