# %%
import numpy as np
import pandas as pd
import random
import math
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import poisson
from scipy.stats import binom
from scipy.stats import geom
from scipy.stats import expon

# %% [markdown]
# ### Q1

# %%
res = (600*0.4*0.75+600*0.6*0.2)
print(res)
print(res/600)
# Out:
# 252.0
# 0.42

# %% [markdown]
# ### Q2

# %% [markdown]
# ### Q3

# %%
tot = 40*0.01+60*0.02
print(tot)
a_prob = (40*0.01)/tot
print(a_prob)
# Out:
# 1.6
# 0.25

# %% [markdown]
# ### Q4

# %% [markdown]
# ### Q5

# %%
mu = 70
sigma = 3

x = 80 
z = (x - mu) / sigma
print(f'Z-score for x={x} is {z}')
# Out:
# Z-score for x=80 is 3.3333333333333335

# %% [markdown]
# ### Q6

# %%
p = 0.5
n = 8

binom_prob = binom.pmf(3, n, p)
print(f'Probability of getting exactly 3 heads in 8 tosses of a fair coin: {binom_prob}')
binom.cdf(2,n,p)
# Out:
# Probability of getting exactly 3 heads in 8 tosses of a fair coin: 0.21874999999999992
# np.float64(0.14453125)

# %% [markdown]
# ### Q7

# %%
a=0.4
b=0.3
c=0.3

ar=5/8
br=4/10
cr=6/10

total_prob = a*ar + b*br + c*cr
print(f'total probability of selecting redball is {total_prob}')
# Out:
# total probability of selecting redball is 0.55

# %% [markdown]
# ### Q8

# %%
sigma = 0.1
sample_size = 20

binom.pmf(5, sample_size, sigma)
# Out:
# np.float64(0.031921361119954424)

# %% [markdown]
# ### Q9

# %%
mails = 10000
spam_spam = 0.5*0.99
spam_not_spam = 0.5*0.05

prob_not_spam = spam_not_spam/(spam_not_spam+spam_spam)
print(prob_not_spam*100)
print(round(prob_not_spam,3))
# Out:
# 4.807692307692308
# 0.048

# %% [markdown]
# ### Q9

# %%
p=0.3
n = 100

binom.pmf(25,n,p)
# Out:
# np.float64(0.04955992276217036)
