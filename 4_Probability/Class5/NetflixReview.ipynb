# %%
import numpy as np
import pandas as pd

# %%
import os as os
assets_path = os.path.join(os.getcwd(), "assets")

df = pd.read_csv("D:\\learning\\ScalerDSML\\assets\\netflix_titles.csv")

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
num_cols = df.select_dtypes(include=['int64']).columns.tolist()
num_cols
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
cat_cols
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
df['show_id'].nunique()
# Out:
# 8807

# %%
df.shape
# Out:
# (8807, 12)

# %%
df['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
import seaborn as sns
sns.countplot(data=df, x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df['director'].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], shape=(4529,), dtype=object)

# %%
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Suhas Kadav                16
# Marcus Raboy               16
# Jay Karas                  14
#                            ..
# James Brown                 1
# Ivona Juka                  1
# Mu Chu                      1
# Chandra Prakash Dwivedi     1
# Majid Al Ansari             1
# Name: count, Length: 4528, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# United States                                    2818
# India                                             972
# United Kingdom                                    419
# Japan                                             245
# South Korea                                       199
#                                                  ...
# Russia, Spain                                       1
# Croatia, Slovenia, Serbia, Montenegro               1
# Japan, Canada                                       1
# United States, France, South Korea, Indonesia       1
# United Arab Emirates, Jordan                        1
# Name: count, Length: 748, dtype: int64

# %%
df[['date_added','release_year']]
# Out:
#               date_added  release_year
# 0     September 25, 2021          2020
# 1     September 24, 2021          2021
# 2     September 24, 2021          2021
# 3     September 24, 2021          2021
# 4     September 24, 2021          2021
# ...                  ...           ...
# 8802   November 20, 2019          2007
# 8803        July 1, 2019          2018
# 8804    November 1, 2019          2009
# 8805    January 11, 2020          2006
# 8806       March 2, 2019          2015
#
# [8807 rows x 2 columns]

# %%
df['date_added'] = pd.to_datetime(df['date_added'],format='mixed')

# %%
df[df['date_added'].dt.year <df['release_year']]
# Out:
#      show_id     type                       title               director  \
# 1551   s1552  TV Show                       Hilda                    NaN
# 1696   s1697  TV Show                Polly Pocket                    NaN
# 2920   s2921  TV Show               Love Is Blind                    NaN
# 3168   s3169  TV Show                Fuller House                    NaN
# 3287   s3288  TV Show          Maradona in Mexico                    NaN
# 3369   s3370  TV Show             BoJack Horseman                    NaN
# 3433   s3434  TV Show            The Hook Up Plan                    NaN
# 4844   s4845  TV Show   Unbreakable Kimmy Schmidt                    NaN
# 4845   s4846  TV Show        Arrested Development                    NaN
# 5394   s5395    Movie  Hans Teeuwen: Real Rancour  Doesjka van Hoogdalem
# 5658   s5659  TV Show                      Sense8                    NaN
# 5677   s5678  TV Show                 Tokyo Trial                    NaN
# ...

# %%
df[df['date_added'].dt.year > df['release_year']]
# Out:
#      show_id     type                                              title  \
# 0         s1    Movie                               Dick Johnson Is Dead
# 7         s8    Movie                                            Sankofa
# 16       s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17       s18  TV Show                                    Falsa identidad
# 21       s22  TV Show                             Resurrection: Ertugrul
# ...      ...      ...                                                ...
# 8802   s8803    Movie                                             Zodiac
# 8803   s8804  TV Show                                        Zombie Dumb
# 8804   s8805    Movie                                         Zombieland
# 8805   s8806    Movie                                               Zoom
# 8806   s8807    Movie                                             Zubaan
#
#                                            director  \
# ...

# %%
df['rating'].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
df['duration'].value_counts()
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 97 min        146
#              ...
# 228 min         1
# 18 min          1
# 205 min         1
# 201 min         1
# 191 min         1
# Name: count, Length: 220, dtype: int64

# %%
df.rename(columns={'listed_in':'genre'}, inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df['genre'].str.split(',')
# Out:
# 0                                         [Documentaries]
# 1       [International TV Shows,  TV Dramas,  TV Myste...
# 2       [Crime TV Shows,  International TV Shows,  TV ...
# 3                               [Docuseries,  Reality TV]
# 4       [International TV Shows,  Romantic TV Shows,  ...
#                               ...
# 8802                   [Cult Movies,  Dramas,  Thrillers]
# 8803           [Kids' TV,  Korean TV Shows,  TV Comedies]
# 8804                           [Comedies,  Horror Movies]
# 8805                [Children & Family Movies,  Comedies]
# 8806    [Dramas,  International Movies,  Music & Music...
# Name: genre, Length: 8807, dtype: object

# %%
all_genre = []
for rows in df['genre'].str.split(','):
    all_genre.extend(rows)
all_genre_unique =list(set(all_genre))

# %%
len(all_genre_unique)
# Out:
# 73

# %%
top_5_popular_gener = pd.Series(all_genre).value_counts().head(5)
top_5_popular_gener
# Out:
#  International Movies    2624
# Dramas                   1600
# Comedies                 1210
# Action & Adventure        859
# Documentaries             829
# Name: count, dtype: int64

# %%
movies=df[df['type']=='Movie']
shows=df[df['type']=='TV Show']

# %%
movies.shape, shows.shape
# Out:
# ((6131, 12), (2676, 12))

# %%
movies['director'].value_counts()
# Out:
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Suhas Kadav                16
# Marcus Raboy               15
# Jay Karas                  14
#                            ..
# Mu Chu                      1
# Chandra Prakash Dwivedi     1
# Majid Al Ansari             1
# Peter Hewitt                1
# Mozez Singh                 1
# Name: count, Length: 4354, dtype: int64

# %%
# movies[movies['genre'] == 'International Movies']['director'].value_counts()
def get_director_by_genre(genre_name):
    for genre in genre_name:
        director_name=movies[movies['genre'].str.contains(genre)]['director'].value_counts().head(1).index
        print(f"top director for {genre} is {director_name}")

get_director_by_genre(genre_name=top_5_popular_gener.index.tolist())
# Out:
# top director for  International Movies is Index(['Cathy Garcia-Molina'], dtype='object', name='director')
# top director for Dramas is Index(['Youssef Chahine'], dtype='object', name='director')
# top director for Comedies is Index(['David Dhawan'], dtype='object', name='director')
# top director for Action & Adventure is Index(['Don Michael Paul'], dtype='object', name='director')
# top director for Documentaries is Index(['Vlad Yudin'], dtype='object', name='director')

# %%
# missing values in each column
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# genre              0
# description        0
# dtype: int64
